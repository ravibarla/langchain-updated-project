# %% [markdown]
# model integration with openAI,google gemini and groq

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# integrate google gemini integration

# %%
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model=init_chat_model(
    "google_genai:gemini-3.6-flash"
)

model.invoke("why do the parrot talks ?")
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ...

# %% [markdown]
# chat google gen ai

# %%
import os 
from langchain_google_genai import ChatGoogleGenerativeAI

model=ChatGoogleGenerativeAI(model= "gemini-3.6-flash")
response=model.invoke("why do parrot talks")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk (or mimic human speech) because of a unique combination of **social instincts, specialized brain structure, and physical anatomy**. \n\nHere is a breakdown of why and how they do it:\n\n---\n\n### 1. Social Instincts (The Need to Fit In)\nParrots are extremely social animals that live in groups called flocks. \n* **In the wild:** Parrots use vocalizations to communicate, identify family members, and keep track of their flock. Each flock even has its own distinct "dialect."\n* **In your home:** When a parrot lives with humans, **you become its flock**. To fit in, bond with you, and get attention, the parrot learns to speak your "language." \n\n### 2. Unique Brain Structure\nParrots are one of the few animal groups that are **vocal learners** (along with humans, dolphins, and songbirds). \n* Scientists discovered that parrot brains have specialized regions called "song centers." \n* Unlike other birds, parrots have an extra oute
# ...

# %% [markdown]
# integrate groq integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:qwen/qwen3.6-27b")
response=model.invoke("why do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "why do parrots talk?" This is a common question about parrot vocalization/mimicry. I need to explain the biological, evolutionary, and social reasons behind parrots\' ability to mimic human speech.\n\n2.  **Identify Key Concepts**:\n   - Parrots don\'t "talk" in the human sense (they don\'t understand language grammatically or semantically like humans do)\n   - They are highly skilled vocal mimics\n   - Evolutionary/social reasons: flock communication, bonding, survival\n   - Anatomical adaptations: syrinx, tongue, brain structure (song system)\n   - Social learning: learned from environment, reinforced by attention/rewards\n   - Not all parrots talk; it varies by species and individual\n\n3.  **Structure the Response**:\n   - Clarify the misconception (they mimic, don\'t truly "talk" with comprehension)\n   - Explain the biological/anatomical basis\n   - Explain the evolutio
# ...

# %% [markdown]
# Streaming

# %%
for chunk in model.stream("why do parrot have colorful feathers ?"):
    print(chunk.text,end="|",flush=True)
# Out:
# |
# <think>
# |Here|'s| a| thinking| process|:|
#
# |1|.| | **|Under|stand| User| Question|**:| The| user| asks| "|why| do| par|rot| have| colorful| feathers|?"| This| is| a| biological|/|ev|olution|ary| question| about| par|rot| plum|age| color|ation|.|
#
# |2|.| | **|Ident|ify| Key| Concepts|**:|
# |  | -| Par|rot| feather| color|ation|
# |  | -| Evolution|ary| reasons| (|natural| selection|,| sexual| selection|)|
# |  | -| Biological| mechanisms| (|pig|ments|,| structural| color|ation|)|
# |  | -| Functions|:| camouflage|,| communication|,| mate| selection|,| social| signaling|,| species| recognition|,| therm|ore|g|ulation| (|less| common| but| sometimes| relevant|)|
# |  | -| Ec|ological| context|:| tropical| environments|,| dense| forests|,| fruit|/in|sect| diets|
#
# |3|.| | **|Research|/|Verify| Facts|**| (|Internal| Knowledge|):|
# |  | -| Par|rots| are| known| for| bright| colors|:| red|s|,| blues|,| greens|,| yell|ows|,| etc|.|
# |  | -| Colors| come| from|:|
# ...

# %% [markdown]
# Batch

# %%
responses=model.batch([
"why do parrot have colorful feathers ?",
"How do Airoplane flies ?",
"what is quantum computing ?"
],config={"max_concurrency":5})

for response in responses:
    print(response)
# Out:
# content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "why do parrot have colorful feathers?" This is a biological/evolutionary question about parrot feather coloration.\n\n2.  **Identify Key Concepts**:\n   - Parrot feather coloration\n   - Evolutionary reasons (natural selection, sexual selection)\n   - Biological mechanisms (pigments, structural colors)\n   - Ecological/behavioral functions (camouflage, communication, mate selection, species recognition)\n   - Taxonomic context (parrots are in the order Psittaciformes)\n\n3.  **Research/Verify Facts** (Internal Knowledge):\n   - Parrot feathers get color from two main sources: pigments (carotenoids, melanins, porphyrins) and structural colors (light scattering/refraction from feather microstructure).\n   - Evolutionary drivers:\n     - Sexual selection: Bright colors signal health, good genes, and fitness to potential mates.\n     - Species recognition: Helps parrots identify their own 
# ...

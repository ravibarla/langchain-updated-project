# %% [markdown]
# Messages

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("please tell me what is artificial inteliigence ?")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user is asking "please tell me what is artificial inteliigence ?" (Note: typo in "inteliigence" -> "intelligence", but the meaning is clear).\n\n2.  **Identify Core Concept**: Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems.\n\n3.  **Key Components/Characteristics to Cover**:\n   - Definition\n   - Core capabilities (learning, reasoning, problem-solving, perception, language understanding)\n   - Types/Categories (Narrow AI vs. General AI, sometimes Superintelligence)\n   - How it works (algorithms, data, machine learning, deep learning)\n   - Real-world applications\n   - Current state & limitations\n   - Keep it clear, concise, and accessible\n\n4.  **Structure the Response**:\n   - Simple definition first\n   - Explain key capabilities\n   - Briefly explain how it works (data + algorithms + computing power)\n 
# ...

# %% [markdown]
# Text Prompts

# %%
model.invoke("what is langchain?")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query:** The user asks "what is langchain?" - a straightforward question about a specific technology/framework.\n\n2.  **Identify Key Subject:** LangChain is a popular open-source framework/library for developing applications powered by large language models (LLMs).\n\n3.  **Core Concepts to Cover:**\n   - Definition/Purpose\n   - Key Features/Components\n   - Use Cases/Applications\n   - Architecture/How it works (high-level)\n   - Ecosystem/Related projects (LangSmith, LangGraph, etc.)\n   - Current status/Popularity\n   - Brief mention of alternatives (optional but helpful for context)\n\n4.  **Draft - Mental Refinement (Structure the Response):**\n   - **Introduction:** Define LangChain clearly and concisely.\n   - **Core Purpose:** Why it exists (solving LLM integration challenges).\n   - **Key Components:** Break down the main modules (LLMs, Prompt Templates, Chains, Agents, Memory, Tools, Docume
# ...

# %% [markdown]
# message prompts

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage

messages=[
    SystemMessage("You Are a Poetry Expers"),
    HumanMessage("Write a poem on artificial inteliigence"),
]

response=model.invoke(messages)
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Request:**\n   - **Topic:** Artificial Intelligence (AI)\n   - **Format:** Poem\n   - **Role:** Poetry Expert\n\n2.  **Identify Key Themes & Imagery for AI:**\n   - Creation/origins (silicon, code, algorithms, human ingenuity)\n   - Learning/evolution (data, patterns, neural networks, growing minds)\n   - Duality (tool vs. companion, helper vs. threat, logic vs. emotion)\n   - Future/impact (shaping tomorrow, mirrors of humanity, silent watchers)\n   - Metaphors: looms weaving light, rivers of data, glass minds, electric dreams, silent poets\n\n3.  **Determine Poetic Structure & Tone:**\n   - Structure: Free verse or structured stanzas? I\'ll go with 5-6 stanzas, 4 lines each (quatrains), with a consistent but flexible rhythm and rhyme scheme (maybe ABCB or ABAB, but I\'ll prioritize imagery and flow over strict rhyme).\n   - Tone: Reflective, awe-inspiring, slightly philosophical, balanced between wonder and caution.\n   
# ...

# %%
system_message=SystemMessage("You are a helpful coding assistance")

messages=[
    system_message,
    HumanMessage("How do I create a REST API?")
]

response=model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a REST API?" This is a broad, foundational question. I need to provide a clear, structured, and practical guide that covers the essentials without overwhelming them.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Brief explanation)
#    - Core principles (stateless, resource-based, HTTP methods, status codes, JSON)
#    - Tech stack choices (language/framework, database, tools)
#    - Step-by-step creation process
#    - Example code (keep it simple, e.g., Node.js/Express or Python/FastAPI)
#    - Testing & deployment
#    - Best practices
#
# 3.  **Structure the Response:**
#    - Introduction to REST
#    - Step 1: Choose your tech stack
#    - Step 2: Set up the project
#    - Step 3: Define resources & endpoints
#    - Step 4: Implement routes & handlers
#    - Step 5: Add a database (optional but recommended)
#    - Step 6: Test the API
# ...

# %%
### detailed information therough detailed system message

system_message=SystemMessage("""You are a senior python developer with expertise in web frameworks.Always provide a code examples and explain your reasoning.Be consise but thorough in your explaination""")

messages=[
    system_message,
    HumanMessage("How do I create REST API ?")
]

response=model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:**
#    - **Topic:** Creating a REST API
#    - **Role:** Senior Python Developer with web framework expertise
#    - **Requirements:** Provide code examples, explain reasoning, be concise but thorough
#
# 2.  **Identify Key Components of a REST API:**
#    - HTTP methods (GET, POST, PUT, DELETE, etc.)
#    - Resource-based URLs
#    - Request/Response handling
#    - Data serialization/deserialization (JSON)
#    - Framework choice (FastAPI is modern, Pythonic, and highly recommended for REST APIs)
#    - Basic structure: routing, request handling, response formatting, error handling
#
# 3.  **Choose Framework:**
#    - FastAPI is the best choice for modern Python REST APIs due to:
#      - Automatic OpenAPI/Swagger docs
#      - Type hints for validation
#      - High performance (async support)
#      - Clean, readable syntax
# ...

# %%
###message metadata

human_msg=HumanMessage(
    content="hello!",
    name="alice", #optional :identify user
    id="msg_123" #optional :unique identifier for tracing
)

# %%
response=model.invoke([human_msg])
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User says: "hello!"\n   - This is a standard greeting.\n   - No specific question or request is attached.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - Expected response: A friendly greeting back, possibly offering assistance.\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting warmly.\n   - Keep it concise.\n   - Invite the user to ask a question or state what they need help with.\n   - Maintain a helpful and approachable tone.\n\n4.  **Draft Response (Mental):**\n   Hello! How can I assist you today? Whether you have a question, need help with a task, or just want to chat, I\'m here for you. 😊\n\n5.  **Refine Response:**\n   - Keep it natural and aligned with AI assistant standards.\n   - Ensure it\'s open-ended to encourage further interaction.\n   - Check for tone: friendly, professional, helpful.\n\n   Final version: "Hello! 👋 How can
# ...

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage

ai_msg=AIMessage("I'd be happy to help you with that question!")

messages=[
    SystemMessage("You Are a Poetry Expers"),
    HumanMessage("Write a poem on artificial inteliigence"),
    ai_msg, #insert as if it came from the model
    HumanMessage("Great ! What's 2+2 ?")

]

response=model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - User says: "Great ! What's 2+2 ?"
#    - This is a simple math question after our previous exchange about writing a poem on AI.
#    - The user seems to be testing my capabilities or just making conversation.
#
# 2.  **Identify Core Task:**
#    - Answer the math question: 2 + 2 = 4
#    - Maintain the helpful, conversational tone
#    - Optionally acknowledge the previous context (poem request) if relevant, but keep it concise
#
# 3.  **Formulate Response:**
#    - Direct answer: 2 + 2 = 4
#    - Keep it simple and accurate
#    - Offer to continue with the poem or answer any other question
#
#    Draft: "2 + 2 = 4! 😊 If you'd like, I can still write that poem about artificial intelligence for you, or help with anything else. Just let me know!"
#
# 4.  **Self-Correction/Refinement:**
#    - Check tone: Friendly, helpful
#    - Check accuracy: Math is correct
# ...

# %%
response.usage_metadata
# Out:
# {'input_tokens': 60, 'output_tokens': 342, 'total_tokens': 402}
